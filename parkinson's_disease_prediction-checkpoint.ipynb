# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# **Data Collection and Analysis**

# %%
df=pd.read_csv("parkinsons.csv")

# %%
df.head(10)
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
# 5  phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 6  phon_R01_S02_1      120.267       137.244       114.820         0.00333
# 7  phon_R01_S02_2      107.332       113.840       104.315         0.00290
# 8  phon_R01_S02_3       95.730       132.068        91.754         0.00551
# 9  phon_R01_S02_4       95.056       120.103        91.226         0.00532
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
# 5           0.00008   0.00463   0.00750     0.01388       0.04701  ...
# 6           0.00003   0.00155   0.00202     0.00466       0.01608  ...
# 7           0.00003   0.00144   0.00182     0.00431       0.01567  ...
# 8           0.00006   0.00293   0.00332     0.00880       0.02093  ...
# 9           0.00006   0.00268   0.00332     0.00803       0.02838  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
# 5      0.06985  0.01222  21.378       1  0.415564  0.825069 -4.242867
# 6      0.02337  0.00607  24.886       1  0.596040  0.764112 -5.634322
# 7      0.02487  0.00344  26.892       1  0.637420  0.763262 -6.167603
# 8      0.03218  0.01070  21.812       1  0.615551  0.773587 -5.498678
# 9      0.04324  0.01022  21.862       1  0.547037  0.798463 -5.011879
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
# 5  0.299111  2.187560  0.357775
# 6  0.257682  1.854785  0.211756
# 7  0.183721  2.064693  0.163755
# 8  0.327769  2.322511  0.231571
# 9  0.325996  2.432792  0.271362
#
# [10 rows x 24 columns]

# %%
pd.set_option("display.max_columns",24)
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# 2             0.00009   0.00544   0.00781     0.01633       0.05233
# 3             0.00009   0.00502   0.00698     0.01505       0.05492
# 4             0.00011   0.00655   0.00908     0.01966       0.06425
# ..                ...       ...       ...         ...           ...
# 190           0.00003   0.00263   0.00259     0.00790       0.04087
# 191           0.00003   0.00331   0.00292     0.00994       0.02751
# 192           0.00008   0.00624   0.00564     0.01873       0.02308
# 193           0.00004   0.00370   0.00390     0.01109       0.02296
# 194           0.00003   0.00295   0.00317     0.00885       0.01884
#
#      MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# 0               0.426       0.02182       0.03130   0.02971      0.06545
# 1               0.626       0.03134       0.04518   0.04368      0.09403
# 2               0.482       0.02757       0.03858   0.03590      0.08270
# 3               0.517       0.02924       0.04005   0.03772      0.08771
# 4               0.584       0.03490       0.04825   0.04465      0.10470
# ..                ...           ...           ...       ...          ...
# 190             0.405       0.02336       0.02498   0.02745      0.07008
# 191             0.263       0.01604       0.01657   0.01879      0.04812
# 192             0.256       0.01268       0.01365   0.01667      0.03804
# 193             0.241       0.01265       0.01321   0.01588      0.03794
# 194             0.190       0.01026       0.01161   0.01373      0.03078
#
#          NHR     HNR  status      RPDE       DFA   spread1   spread2  \
# 0    0.02211  21.033       1  0.414783  0.815285 -4.813031  0.266482
# 1    0.01929  19.085       1  0.458359  0.819521 -4.075192  0.335590
# 2    0.01309  20.651       1  0.429895  0.825288 -4.443179  0.311173
# 3    0.01353  20.644       1  0.434969  0.819235 -4.117501  0.334147
# 4    0.01767  19.649       1  0.417356  0.823484 -3.747787  0.234513
# ..       ...     ...     ...       ...       ...       ...       ...
# 190  0.02764  19.517       0  0.448439  0.657899 -6.538586  0.121952
# 191  0.01810  19.147       0  0.431674  0.683244 -6.195325  0.129303
# 192  0.10715  17.883       0  0.407567  0.655683 -6.787197  0.158453
# 193  0.07223  19.020       0  0.451221  0.643956 -6.744577  0.207454
# 194  0.04398  21.209       0  0.462803  0.664357 -5.724056  0.190667
#
#            D2       PPE
# 0    2.301442  0.284654
# 1    2.486855  0.368674
# 2    2.342259  0.332634
# 3    2.405554  0.368975
# 4    2.332180  0.410335
# ..        ...       ...
# 190  2.657476  0.133050
# 191  2.784312  0.168895
# 192  2.679772  0.131728
# 193  2.138608  0.123306
# 194  2.555477  0.148569
#
# [195 rows x 24 columns]

# %%
df.shape #number of rows and columns
# Out:
# (195, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
#  16  HNR               195 non-null    float64
#  17  status            195 non-null    int64
#  18  RPDE              195 non-null    float64
#  19  DFA               195 non-null    float64
#  20  spread1           195 non-null    float64
#  21  spread2           195 non-null    float64
#  22  D2                195 non-null    float64
#  23  PPE               195 non-null    float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 36.7+ KB

# %%
df.isnull().any() #to check if any null values are present
# Out:
# name                False
# MDVP:Fo(Hz)         False
# MDVP:Fhi(Hz)        False
# MDVP:Flo(Hz)        False
# MDVP:Jitter(%)      False
# MDVP:Jitter(Abs)    False
# MDVP:RAP            False
# MDVP:PPQ            False
# Jitter:DDP          False
# MDVP:Shimmer        False
# MDVP:Shimmer(dB)    False
# Shimmer:APQ3        False
# Shimmer:APQ5        False
# MDVP:APQ            False
# Shimmer:DDA         False
# NHR                 False
# HNR                 False
# status              False
# RPDE                False
# DFA                 False
# spread1             False
# spread2             False
# D2                  False
# PPE                 False
# dtype: bool

# %% [markdown]
# **getting statistical measures/analysis**

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5    MDVP:APQ  Shimmer:DDA  \
# count        195.000000    195.000000    195.000000  195.000000   195.000000
# mean           0.282251      0.015664      0.017878    0.024081     0.046993
# std            0.194877      0.010153      0.012024    0.016947     0.030459
# min            0.085000      0.004550      0.005700    0.007190     0.013640
# 25%            0.148500      0.008245      0.009580    0.013080     0.024735
# 50%            0.221000      0.012790      0.013470    0.018260     0.038360
# 75%            0.350000      0.020265      0.022380    0.029400     0.060795
# max            1.302000      0.056470      0.079400    0.137780     0.169420
#
#               NHR         HNR      status        RPDE         DFA     spread1  \
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.024847   21.885974    0.753846    0.498536    0.718099   -5.684397
# std      0.040418    4.425764    0.431878    0.103942    0.055336    1.090208
# min      0.000650    8.441000    0.000000    0.256570    0.574282   -7.964984
# 25%      0.005925   19.198000    1.000000    0.421306    0.674758   -6.450096
# 50%      0.011660   22.085000    1.000000    0.495954    0.722254   -5.720868
# 75%      0.025640   25.075500    1.000000    0.587562    0.761881   -5.046192
# max      0.314820   33.047000    1.000000    0.685151    0.825288   -2.434031
#
#           spread2          D2         PPE
# count  195.000000  195.000000  195.000000
# mean     0.226510    2.381826    0.206552
# std      0.083406    0.382799    0.090119
# min      0.006274    1.423287    0.044539
# 25%      0.174351    2.099125    0.137451
# 50%      0.218885    2.361532    0.194052
# 75%      0.279234    2.636456    0.252980
# max      0.450493    3.671155    0.527367

# %%
df["status"].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %% [markdown]
# 0--> Healthy ,
# 1-->Parkinson's disease

# %%
X=df.drop(columns=['name','status'],axis=1)
y=df['status']

# %%
X
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# 2             0.00009   0.00544   0.00781     0.01633       0.05233
# 3             0.00009   0.00502   0.00698     0.01505       0.05492
# 4             0.00011   0.00655   0.00908     0.01966       0.06425
# ..                ...       ...       ...         ...           ...
# 190           0.00003   0.00263   0.00259     0.00790       0.04087
# 191           0.00003   0.00331   0.00292     0.00994       0.02751
# 192           0.00008   0.00624   0.00564     0.01873       0.02308
# 193           0.00004   0.00370   0.00390     0.01109       0.02296
# 194           0.00003   0.00295   0.00317     0.00885       0.01884
#
#      MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# 0               0.426       0.02182       0.03130   0.02971      0.06545
# 1               0.626       0.03134       0.04518   0.04368      0.09403
# 2               0.482       0.02757       0.03858   0.03590      0.08270
# 3               0.517       0.02924       0.04005   0.03772      0.08771
# 4               0.584       0.03490       0.04825   0.04465      0.10470
# ..                ...           ...           ...       ...          ...
# 190             0.405       0.02336       0.02498   0.02745      0.07008
# 191             0.263       0.01604       0.01657   0.01879      0.04812
# 192             0.256       0.01268       0.01365   0.01667      0.03804
# 193             0.241       0.01265       0.01321   0.01588      0.03794
# 194             0.190       0.01026       0.01161   0.01373      0.03078
#
#          NHR     HNR      RPDE       DFA   spread1   spread2        D2  \
# 0    0.02211  21.033  0.414783  0.815285 -4.813031  0.266482  2.301442
# 1    0.01929  19.085  0.458359  0.819521 -4.075192  0.335590  2.486855
# 2    0.01309  20.651  0.429895  0.825288 -4.443179  0.311173  2.342259
# 3    0.01353  20.644  0.434969  0.819235 -4.117501  0.334147  2.405554
# 4    0.01767  19.649  0.417356  0.823484 -3.747787  0.234513  2.332180
# ..       ...     ...       ...       ...       ...       ...       ...
# 190  0.02764  19.517  0.448439  0.657899 -6.538586  0.121952  2.657476
# 191  0.01810  19.147  0.431674  0.683244 -6.195325  0.129303  2.784312
# 192  0.10715  17.883  0.407567  0.655683 -6.787197  0.158453  2.679772
# 193  0.07223  19.020  0.451221  0.643956 -6.744577  0.207454  2.138608
# 194  0.04398  21.209  0.462803  0.664357 -5.724056  0.190667  2.555477
#
#           PPE
# 0    0.284654
# 1    0.368674
# 2    0.332634
# 3    0.368975
# 4    0.410335
# ..        ...
# 190  0.133050
# 191  0.168895
# 192  0.131728
# 193  0.123306
# 194  0.148569
#
# [195 rows x 22 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (136, 22) (59, 22) (136,) (59,)

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# **Model 1:-**

# %%
model1=SVC()

# %%
model1.fit(X_train,y_train)
# Out:
# SVC()

# %% [markdown]
# **prediction on test data**

# %%
y_pred=model1.predict(X_test)

# %% [markdown]
# **prediction on train data**

# %%
y_pred_train=model1.predict(X_train)

# %% [markdown]
# **accuracy score for training data**

# %%
print("accuracy_score for train data:-",accuracy_score(y_train,y_pred_train))
# Out:
# accuracy_score for train data:- 0.8823529411764706

# %% [markdown]
# **accuracy score for test data**

# %%
print("accuracy_score for test data:-",accuracy_score(y_test,y_pred))
# Out:
# accuracy_score for test data:- 0.8813559322033898

# %% [markdown]
# **classification_report:**

# %%
print("classification_report:-\n",classification_report(y_test,y_pred))
# Out:
# classification_report:-
#                precision    recall  f1-score   support
#
#            0       1.00      0.53      0.70        15
#            1       0.86      1.00      0.93        44
#
#     accuracy                           0.88        59
#    macro avg       0.93      0.77      0.81        59
# weighted avg       0.90      0.88      0.87        59

# %% [markdown]
# **confusion_matrix:**

# %%
print("confusion_matrix:-\n",(confusion_matrix(y_test,y_pred)))
# Out:
# confusion_matrix:-
#  [[ 8  7]
#  [ 0 44]]

# %% [markdown]
# **model2:-Decision tree classifier**

# %%
model2=DecisionTreeClassifier()

# %% [markdown]
# **hyperparameter tunning**

# %%
param={'criterion': ["gini", "entropy", "log_loss"],
     'splitter':["best", "random"],
     'max_depth':[1,2,3,4,5,None],
      'min_samples_split':[1,2,3,4,5]}
grid=GridSearchCV(model2,param_grid=param,scoring='accuracy',cv=5)

# %%
grid.fit(X_train,y_train)
# Out:
# C:\Users\win10\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 180 fits failed out of a total of 900.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\win10\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\win10\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\win10\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\win10\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\win10\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.81666667 0.82380952 0.80925926 0.75767196
#  0.80925926 0.79470899 0.81666667 0.80925926        nan        nan
#  0.80925926 0.82354497 0.80925926 0.8015873  0.81666667 0.82328042
#  0.80925926 0.8015873         nan        nan 0.82354497 0.80846561
#  0.83095238 0.82354497 0.80873016 0.81560847 0.79391534 0.80873016
#         nan        nan 0.83862434 0.88227513 0.82433862 0.82380952
#  0.83915344 0.86005291 0.83174603 0.84603175        nan        nan
#  0.87513228 0.79444444 0.84603175 0.88994709 0.8531746  0.87513228
#  0.83121693 0.86746032        nan        nan 0.8462963  0.88968254
#  0.8457672  0.88253968 0.83121693 0.84550265 0.83148148 0.86719577
#         nan        nan 0.76481481 0.79444444 0.76481481 0.78703704
#  0.76481481 0.76481481 0.76481481 0.76481481        nan        nan
#  0.8526455  0.78703704 0.8452381  0.77248677 0.8452381  0.80925926
#  0.8452381  0.83862434        nan        nan 0.83756614 0.84550265
#  0.84497354 0.82407407 0.83756614 0.83862434 0.83756614 0.81613757
#         nan        nan 0.85238095 0.8015873  0.85238095 0.83174603
#  0.86719577 0.83095238 0.85238095 0.81666667        nan        nan
#  0.86005291 0.85343915 0.86719577 0.81640212 0.87486772 0.82354497
#  0.86005291 0.86084656        nan        nan 0.86719577 0.8526455
#  0.86719577 0.89761905 0.84497354 0.88253968 0.86719577 0.85291005
#         nan        nan 0.76481481 0.75634921 0.76481481 0.76481481
#  0.76481481 0.72777778 0.76481481 0.78703704        nan        nan
#  0.8452381  0.83095238 0.8452381  0.8010582  0.8452381  0.77989418
#  0.8526455  0.81613757        nan        nan 0.83756614 0.81613757
#  0.84497354 0.80846561 0.84497354 0.81666667 0.83756614 0.84550265
#         nan        nan 0.85978836 0.81560847 0.85978836 0.87486772
#  0.85978836 0.82380952 0.85978836 0.85952381        nan        nan
#  0.86005291 0.85291005 0.85238095 0.80079365 0.87460317 0.8531746
#  0.86719577 0.86772487        nan        nan 0.87460317 0.87513228
#  0.85978836 0.87539683 0.86719577 0.87539683 0.86719577 0.87566138]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5, None],
#                          'min_samples_split': [1, 2, 3, 4, 5],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %% [markdown]
# **getting best parameters selected by hyperparameter tunning**

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'min_samples_split': 3,
#  'splitter': 'random'}

# %% [markdown]
# **Prediction on training data:-**

# %%
y_pred_train_model2=grid.predict(X_train)

# %% [markdown]
# **accuracy_score for training data:-**

# %%
print("accuracy_score for training data:-",accuracy_score(y_train,y_pred_train_model2))
# Out:
# accuracy_score for training data:- 1.0

# %% [markdown]
# **Prediction on test data:-**

# %%
y_pred1=grid.predict(X_test)

# %% [markdown]
# **accuracy_score for test data:-**

# %%
print("accuracy_score for test data:-",accuracy_score(y_test,y_pred1))
# Out:
# accuracy_score for test data:- 0.8813559322033898

# %% [markdown]
# **Classification report for model2:-**

# %%
print("classification_report:-\n",classification_report(y_test,y_pred1))
# Out:
# classification_report:-
#                precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76        15
#            1       0.91      0.93      0.92        44
#
#     accuracy                           0.88        59
#    macro avg       0.85      0.83      0.84        59
# weighted avg       0.88      0.88      0.88        59

# %%
dt_model=DecisionTreeClassifier(**grid.best_params_)
dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=3,
#                        splitter='random')

# %%
from sklearn import tree
plt.figure(figsize=(20,7))
tree.plot_tree(dt_model,filled=True)
# Out:
# [Text(0.6666666666666666, 0.9642857142857143, 'x[21] <= 0.367\nentropy = 0.799\nsamples = 136\nvalue = [33, 103]'),
#  Text(0.6111111111111112, 0.8928571428571429, 'x[2] <= 2.124\nentropy = 0.932\nsamples = 95\nvalue = [33, 62]'),
#  Text(0.5555555555555556, 0.8214285714285714, 'x[12] <= -0.006\nentropy = 0.876\nsamples = 88\nvalue = [26, 62]'),
#  Text(0.5, 0.75, 'x[18] <= -0.795\nentropy = 0.935\nsamples = 74\nvalue = [26, 48]'),
#  Text(0.2777777777777778, 0.6785714285714286, 'x[13] <= -0.585\nentropy = 0.988\nsamples = 23\nvalue = [13.0, 10.0]'),
#  Text(0.16666666666666666, 0.6071428571428571, 'x[0] <= 1.008\nentropy = 0.989\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.1111111111111111, 0.5357142857142857, 'x[21] <= -0.912\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.05555555555555555, 0.4642857142857143, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.16666666666666666, 0.4642857142857143, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2222222222222222, 0.5357142857142857, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.3888888888888889, 0.6071428571428571, 'x[20] <= 0.95\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.3333333333333333, 0.5357142857142857, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4444444444444444, 0.5357142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7222222222222222, 0.6785714285714286, 'x[0] <= -0.211\nentropy = 0.819\nsamples = 51\nvalue = [13, 38]'),
#  Text(0.6111111111111112, 0.6071428571428571, 'x[20] <= -0.179\nentropy = 0.967\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.5555555555555556, 0.5357142857142857, 'x[8] <= -0.494\nentropy = 0.998\nsamples = 21\nvalue = [11, 10]'),
#  Text(0.5, 0.4642857142857143, 'x[10] <= -0.966\nentropy = 0.964\nsamples = 18\nvalue = [11, 7]'),
#  Text(0.4444444444444444, 0.39285714285714285, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5555555555555556, 0.39285714285714285, 'x[13] <= -0.584\nentropy = 0.896\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.5, 0.32142857142857145, 'x[2] <= 0.06\nentropy = 0.75\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.4444444444444444, 0.25, 'x[5] <= -0.509\nentropy = 0.619\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.3888888888888889, 0.17857142857142858, 'x[6] <= -0.496\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.3333333333333333, 0.10714285714285714, 'x[16] <= 1.145\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2777777777777778, 0.03571428571428571, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3888888888888889, 0.03571428571428571, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4444444444444444, 0.10714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.17857142857142858, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.5555555555555556, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6111111111111112, 0.32142857142857145, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6111111111111112, 0.4642857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6666666666666666, 0.5357142857142857, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8333333333333334, 0.6071428571428571, 'x[1] <= 0.367\nentropy = 0.426\nsamples = 23\nvalue = [2, 21]'),
#  Text(0.7777777777777778, 0.5357142857142857, 'entropy = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.8888888888888888, 0.5357142857142857, 'x[5] <= -0.193\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.8333333333333334, 0.4642857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9444444444444444, 0.4642857142857143, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6111111111111112, 0.75, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.6666666666666666, 0.8214285714285714, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7222222222222222, 0.8928571428571429, 'entropy = 0.0\nsamples = 41\nvalue = [0, 41]')]

# %% [markdown]
# **Model3**

# %%
model3=LogisticRegression()

# %%
model3.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Prediction on test data**

# %%
y_pred_model3=model3.predict(X_test)

# %% [markdown]
# **Accuracy for test data**

# %%
print("accuracy_score for test data:-",accuracy_score(y_test,y_pred_model3))
# Out:
# accuracy_score for test data:- 0.864406779661017

# %% [markdown]
# **Prediction on training data**

# %%
y_pred_model3_train=model3.predict(X_train)

# %% [markdown]
# **Accuracy for training data**

# %%
print("accuracy_score for training data:-",accuracy_score(y_train,y_pred_model3_train))
# Out:
# accuracy_score for training data:- 0.8823529411764706

# %% [markdown]
# **Classification report for model3:-**

# %%
print("classification_report:-\n",classification_report(y_test,y_pred_model3))
# Out:
# classification_report:-
#                precision    recall  f1-score   support
#
#            0       0.82      0.60      0.69        15
#            1       0.88      0.95      0.91        44
#
#     accuracy                           0.86        59
#    macro avg       0.85      0.78      0.80        59
# weighted avg       0.86      0.86      0.86        59

# %% [markdown]
# **Model4:-**

# %%
model4=VotingClassifier(
   [ ('M1',dt_model),
    ('M2',model3)],
voting='soft')

# %%
model4.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('M1',
#                               DecisionTreeClassifier(criterion='entropy',
#                                                      min_samples_split=3,
#                                                      splitter='random')),
#                              ('M2', LogisticRegression())],
#                  voting='soft')

# %% [markdown]
# **Prediction on test data**

# %%
y_pred4=model4.predict(X_test)

# %% [markdown]
# **Accuracy score for test data**

# %%
print("accuracy_score for test data:-",accuracy_score(y_test,y_pred4))
# Out:
# accuracy_score for test data:- 0.9322033898305084

# %% [markdown]
# **Prediction on training data**

# %%
y_pred4_train=model4.predict(X_train)

# %% [markdown]
# **Accuracy on training data**

# %%
print("accuracy_score for test data:-",accuracy_score(y_train,y_pred4_train))
# Out:
# accuracy_score for test data:- 1.0

# %% [markdown]
# **Classification report**

# %%
print("classification_report:-\n",classification_report(y_test,y_pred4))
# Out:
# classification_report:-
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        15
#            1       0.95      0.95      0.95        44
#
#     accuracy                           0.93        59
#    macro avg       0.91      0.91      0.91        59
# weighted avg       0.93      0.93      0.93        59

# %%
data={"SVC":0.8813559322033898,"DecisionTree":0.8983050847457628,'LogisticRegression':0.864406779661017,'VotingClassifier': 0.9322033898305084}
result=pd.DataFrame(data,index=["accuracy_score"])

# %%
result
# Out:
#                      SVC  DecisionTree  LogisticRegression  VotingClassifier
# accuracy_score  0.881356      0.898305            0.864407          0.932203
